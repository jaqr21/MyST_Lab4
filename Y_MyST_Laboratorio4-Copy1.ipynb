# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://www.carrerasenlinea.mx/logos/original/logo-instituto-tecnologico-y-de-estudios-superiores-de-occidente.png" width="150px" height="100px" />
#
# # Laboratorio 4 y 5: Análisis Fundamental
#
#
# - Poder describir los efectos cuantitativos en el precio durante los comunicados de indicadores macroeconómicos, así como el detectar oportunidades de inversión a partir de los resultados obtenidos. Lo anterior, utilizando lo que se conoce como "Calendario Económico", y más en particular, aquel que incorpora información de las principales economías del mundo por lo que es ampliamiente utilizado en el mercado de Forex.El propósito: Que utilices la información histórica de la cuenta de trading manual y, mediante la formulación y programación de 3 "Sesgos cognitivos", realices una evaluación del desempeño de la cuenta utilizando el marco de "Behavioral economics". Con la finalidad de inferir si al momento de tomar las decisiones que se tomaron en esa cuenta, se estuvo incurriendo en esos "Sesgos cognitivos" y su impacto en el resultado final.
#
#
# #### Equipo Y:
#
# * José Antonio Quintero Rodríguez
# * Paulina Rodríguez Guerrero
# * Diego Velasco Sánchez

# %%
import pandas as pd
#from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### IMPORTACION DE DATOS

# %%
#archivo de calendario económico
archivo = pd.read_csv('calendario_economico.csv')
archivo['timestamp'] = pd.to_datetime(archivo['timestamp'])
archivo['timestamp'] = archivo['timestamp'].dt.tz_localize('UTC')
archivo.head(5)
# Out:
#                   timestamp Currency                         Name  \
# 0 2009-01-05 09:30:00+00:00      EUR   Sentix Investor Confidence
# 1 2009-01-05 15:00:00+00:00      USD  Construction Spending (MoM)
# 2 2009-01-06 08:55:00+00:00      EUR          Markit Services PMI
# 3 2009-01-06 09:00:00+00:00      EUR          Markit Services PMI
# 4 2009-01-06 10:00:00+00:00      EUR   Consumer Price Index (YoY)
#
#                    Country  Volatility  actual  previous  consensus
# 0  European Monetary Union           1   -34.4     -42.3        NaN
# 1            United States           1    -1.2      -0.4       -1.3
# 2                  Germany           1    46.6      46.4       46.4
# 3  European Monetary Union           0    42.1      42.0       42.0
# 4  European Monetary Union           2     1.6       2.1        1.8

# %%
#archivo de precios 2019
archivop_2019=pd.read_csv('precios_historicos_eurusd_2019.csv')
archivop_2019['timestamp'] = pd.to_datetime(archivop_2019['timestamp'])
archivop_2019['timestamp'] = archivop_2019['timestamp'].dt.tz_localize('UTC')
archivop_2019.head(5)
# Out:
#                   timestamp     open     high      low    close
# 0 2019-01-01 22:00:00+00:00  1.14649  1.14658  1.14634  1.14658
# 1 2019-01-01 22:05:00+00:00  1.14658  1.14658  1.14635  1.14635
# 2 2019-01-01 22:10:00+00:00  1.14635  1.14636  1.14632  1.14632
# 3 2019-01-01 22:15:00+00:00  1.14632  1.14632  1.14632  1.14632
# 4 2019-01-01 22:20:00+00:00  1.14653  1.14653  1.14653  1.14653

# %%
#archivo de precios histórico
archivoph=pd.read_csv('precios_historicos_eurusd.csv')
archivoph['timestamp'] = pd.to_datetime(archivoph['timestamp'])
archivoph['timestamp'] = archivoph['timestamp'].dt.tz_localize('UTC')
archivoph.head(5)
# Out:
#                   timestamp     open     high      low    close
# 0 2009-01-06 05:00:00+00:00  1.35564  1.35565  1.35383  1.35439
# 1 2009-01-06 05:05:00+00:00  1.35443  1.35489  1.35424  1.35474
# 2 2009-01-06 05:10:00+00:00  1.35480  1.35552  1.35439  1.35539
# 3 2009-01-06 05:15:00+00:00  1.35545  1.35549  1.35101  1.35101
# 4 2009-01-06 05:20:00+00:00  1.35101  1.35130  1.35021  1.35086

# %% [markdown]
# ### SELECCION DE INDICADORES

# %% [markdown]
# #### PRIMER INDICADOR

# %%
filtro_usa = archivo[((archivo['Country'] == "United States"))
     & ((archivo['Name'] == 'Consumer Price Index (MoM)'))].reset_index(drop=True)
filtro_usa.head()
# Out:
#                   timestamp Currency                        Name  \
# 0 2009-01-16 13:30:00+00:00      USD  Consumer Price Index (MoM)
# 1 2009-02-20 13:30:00+00:00      USD  Consumer Price Index (MoM)
# 2 2009-03-18 12:30:00+00:00      USD  Consumer Price Index (MoM)
# 3 2009-04-15 12:30:00+00:00      USD  Consumer Price Index (MoM)
# 4 2009-05-15 12:30:00+00:00      USD  Consumer Price Index (MoM)
#
#          Country  Volatility  actual  previous  consensus
# 0  United States           2    -0.8      -1.7       -0.9
# 1  United States           2     0.3      -0.8        0.3
# 2  United States           2     0.4       0.3        0.3
# 3  United States           2    -0.1       0.4        0.1
# 4  United States           2     0.0      -0.1        0.0

# %% [markdown]
# #### SEGUNDO INDICADOR

# %%
filtro_ue = archivo[((archivo['Country'] == "European Monetary Union"))
     & ((archivo['Name'] == 'Consumer Price Index (MoM)'))].reset_index(drop=True)
filtro_ue.head()
# Out:
#                   timestamp Currency                        Name  \
# 0 2009-01-15 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 1 2009-02-27 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 2 2009-03-16 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 3 2009-04-16 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 4 2009-05-15 09:00:00+00:00      EUR  Consumer Price Index (MoM)
#
#                    Country  Volatility  actual  previous  consensus
# 0  European Monetary Union           2    -0.1      -0.5       -0.1
# 1  European Monetary Union           2    -0.8      -0.1       -0.9
# 2  European Monetary Union           2     0.4      -0.8        0.4
# 3  European Monetary Union           2     0.4       0.4        0.4
# 4  European Monetary Union           2     0.4       0.4        0.4

# %% [markdown]
# ### LIMPIAR DATOS

# %%
#primer indicador
limp1 = filtro_usa[filtro_usa['consensus'].isna()].index # Encontrando row de los NaN en 'Consensus'
filtro_usa.iloc[limp1,7] = filtro_usa.iloc[limp1,6] # Reemplazando 'Consensus' con 'Previous'
filtro_usa.head()
# Out:
#    index                 timestamp Currency                        Name  \
# 0     80 2009-01-16 13:30:00+00:00      USD  Consumer Price Index (MoM)
# 1    242 2009-02-20 13:30:00+00:00      USD  Consumer Price Index (MoM)
# 2    395 2009-03-18 12:30:00+00:00      USD  Consumer Price Index (MoM)
# 3    526 2009-04-15 12:30:00+00:00      USD  Consumer Price Index (MoM)
# 4    688 2009-05-15 12:30:00+00:00      USD  Consumer Price Index (MoM)
#
#          Country  Volatility  actual  previous  consensus
# 0  United States           2    -0.8      -1.7       -0.9
# 1  United States           2     0.3      -0.8        0.3
# 2  United States           2     0.4       0.3        0.3
# 3  United States           2    -0.1       0.4        0.1
# 4  United States           2     0.0      -0.1        0.0

# %%
#segundo indicador
limp2 = filtro_ue[filtro_ue['consensus'].isna()].index # Encontrando row de los NaN en 'Consensus'
filtro_ue.iloc[limp2,7] = filtro_ue.iloc[limp2,6] # Reemplazando 'Consensus' con 'Previous'
filtro_ue.tail(20)
# Out:
#      index                 timestamp Currency                        Name  \
# 109  26616 2018-02-23 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 110  26859 2018-03-16 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 111  27200 2018-04-18 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 112  27532 2018-05-16 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 113  27868 2018-06-15 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 114  28208 2018-07-18 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 115  28510 2018-08-17 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 116  28815 2018-09-17 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 117  29151 2018-10-17 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 118  29489 2018-11-16 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 119  29835 2018-12-17 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 120  30097 2019-01-17 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 121  30466 2019-02-22 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 122  30728 2019-03-15 10:00:00+00:00      EUR  Consumer Price Index (MoM)
# 123  31075 2019-04-17 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 124  31430 2019-05-17 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 125  31764 2019-06-18 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 126  32110 2019-07-17 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 127  32428 2019-08-19 09:00:00+00:00      EUR  Consumer Price Index (MoM)
# 128  32755 2019-09-18 09:00:00+00:00      EUR  Consumer Price Index (MoM)
#
#                      Country  Volatility  actual  previous  consensus
# 109  European Monetary Union           2    -0.9       0.4       -0.9
# 110  European Monetary Union           2     0.2      -0.9        0.2
# 111  European Monetary Union           2     1.0       0.2        1.0
# 112  European Monetary Union           2     0.3       1.0        0.3
# 113  European Monetary Union           2     0.5       0.3        0.5
# 114  European Monetary Union           2     0.1       0.5        0.1
# 115  European Monetary Union           2    -0.3       0.1       -0.3
# 116  European Monetary Union           2     0.2      -0.3        0.2
# 117  European Monetary Union           2     0.5       0.2        0.5
# 118  European Monetary Union           2     0.2       0.5        0.2
# 119  European Monetary Union           2    -0.2       0.2       -0.2
# 120  European Monetary Union           2     0.0      -0.2        0.0
# 121  European Monetary Union           2    -1.0       0.0       -1.1
# 122  European Monetary Union           2     0.3      -1.0        0.3
# 123  European Monetary Union           2     1.0       0.3        1.0
# 124  European Monetary Union           2     0.7       1.0        0.7
# 125  European Monetary Union           2     0.1       0.7        0.2
# 126  European Monetary Union           2     0.2       0.1        0.1
# 127  European Monetary Union           2    -0.5       0.2       -0.4
# 128  European Monetary Union           2     0.1      -0.5        0.2

# %% [markdown]
# ### VLOOKUP TIMESTAMP DE PRECIOS CON TIMESTAMP DE CALENDARIO ECONOMICO

# %%
#vlookup primer filtro por el timestamp
vlookup_usa = list(archivop.loc[archivop['timestamp'].isin(filtro_usa['timestamp'])]['timestamp'])

#vlookup segundo filtro por el timestamp
vlookup_ue = list(archivop.loc[archivop['timestamp'].isin(filtro_ue['timestamp'])]['timestamp'])

# %%
#traer los precios del vloolup_usa
dic_usa = {}
for i in range(len(vlookup_usa)):
    filtro_usa= archivop.loc[archivop['timestamp'] == vlookup_usa[i]].index.values[0] 
    final = filtro_usa + 6 # 30 despues
    principio = filtro_usa - 6 # 30 antes
    p1 = archivop.iloc[principio:final+1, :].reset_index().drop('index',1) 
    dic_usa[vlookup_usa[i]] = p1 # guardar en nuestro dic vacio

# %%
#traer los precios del vloolup_ue
dic_ue = {}
for i in range(len(vlookup_usa)):
    filtro_ue= archivop.loc[archivop['timestamp'] == vlookup_usa[i]].index.values[0] 
    final = filtro_ue + 6 # 30 despues
    principio = filtro_ue - 6 # 30 antes
    p2 = archivop.iloc[principio:final+1, :].reset_index().drop('index',1) 
    dic_ue[vlookup_ue[i]] = p2 # guardar en nuestro dic vacio

# %% [markdown]
# ### DEFINIR ESCENARIOS

# %% [markdown]
# * ESCENARIO 1: A Actual >= Consensus >= Previous
# * ESCENARIO 2: B Actual >= Consensus < Previous
# * ESCENARIO 3: C Actual < Consensus >= Previous
# * ESCENARIO 4: D Actual < Consensus < Previous
